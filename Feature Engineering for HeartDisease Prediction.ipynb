# %% [markdown]
# # Feature Engineering for HeartDisease Prediction

# %% [markdown]
# ## 1.Data Exploration

# %%
import pandas as pd
df = pd.read_csv('heart_disease_uci.csv')

# %%
df.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
# Display the first 5 rows of the dataset
print(df.head())
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
# Identify numerical features
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns
print("Numerical features:", numerical_features)

# Identify categorical features
categorical_features = df.select_dtypes(include=['object']).columns
print("Categorical features:", categorical_features)
# Out:
# Numerical features: Index(['id', 'age', 'trestbps', 'chol', 'thalch', 'oldpeak', 'ca', 'num'], dtype='object')
# Categorical features: Index(['sex', 'dataset', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'thal'], dtype='object')

# %%
df.isnull().sum()
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64

# %%
df.dtypes
# Out:
# id            int64
# age           int64
# sex          object
# dataset      object
# cp           object
# trestbps    float64
# chol        float64
# fbs          object
# restecg      object
# thalch      float64
# exang        object
# oldpeak     float64
# slope        object
# ca          float64
# thal         object
# num           int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
df.isnull().sum()
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64

# %% [markdown]
# ## 2. Handling Missing Data

# %%
df['thal'].fillna(df['thal'].mode()[0], inplace=True)
df['ca'].fillna(df['ca'].mode()[0], inplace=True)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 904  905   57    Male  VA Long Beach     asymptomatic     130.0  207.0  False
# 908  909   74    Male  VA Long Beach     asymptomatic     155.0  310.0  False
# 910  911   51  Female  VA Long Beach     asymptomatic     114.0  258.0   True
# 911  912   62    Male  VA Long Beach     asymptomatic     160.0  254.0   True
# 912  913   53    Male  VA Long Beach     asymptomatic     144.0  300.0   True
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# 0      lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1      lv hypertrophy   108.0   True      1.5         flat  3.0
# 2      lv hypertrophy   129.0   True      2.6         flat  2.0
# 3              normal   187.0  False      3.5  downsloping  0.0
# 4      lv hypertrophy   172.0  False      1.4    upsloping  0.0
# ..                ...     ...    ...      ...          ...  ...
# 904  st-t abnormality    96.0   True      1.0         flat  0.0
# 908            normal   112.0   True      1.5  downsloping  0.0
# 910    lv hypertrophy    96.0  False      1.0    upsloping  0.0
# 911  st-t abnormality   108.0   True      3.0         flat  0.0
# 912  st-t abnormality   128.0   True      1.5         flat  0.0
#
#                   thal  num
# 0         fixed defect    0
# 1               normal    2
# 2    reversable defect    1
# 3               normal    0
# 4               normal    0
# ..                 ...  ...
# 904             normal    0
# 908             normal    2
# 910             normal    0
# 911             normal    4
# 912             normal    3
#
# [531 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# id          0
# age         0
# sex         0
# dataset     0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalch      0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %% [markdown]
# ## 3. Feature Creation

# %%
bins = [0, 40, 60, 100]
labels = ['<40', '40-60', '>60']
df['AgeGroup'] = pd.cut(df['age'], bins=bins, labels=labels)

# %%
def cholesterol_level(chol):
    if chol < 200:
        return 'Low'
    elif 200 <= chol <= 239:
        return 'Normal'
    else:
        return 'High'

df['CholesterolLevel'] = df['chol'].apply(cholesterol_level)

# %%
df['IsRisk'] = ((df['chol'] > 240) | (df['trestbps'] > 140) | (df['age'] > 60)).astype(int)

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# 0      lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1      lv hypertrophy   108.0   True      1.5         flat  3.0
# 2      lv hypertrophy   129.0   True      2.6         flat  2.0
# 3              normal   187.0  False      3.5  downsloping  0.0
# 4      lv hypertrophy   172.0  False      1.4    upsloping  0.0
# ..                ...     ...    ...      ...          ...  ...
# 915  st-t abnormality   154.0  False      0.0          NaN  NaN
# 916  st-t abnormality     NaN    NaN      NaN          NaN  NaN
# 917  st-t abnormality   100.0  False      0.0          NaN  NaN
# 918    lv hypertrophy     NaN    NaN      NaN          NaN  NaN
# 919    lv hypertrophy    93.0   True      0.0          NaN  NaN
#
#                   thal  num
# 0         fixed defect    0
# 1               normal    2
# 2    reversable defect    1
# 3               normal    0
# 4               normal    0
# ..                 ...  ...
# 915                NaN    1
# 916                NaN    0
# 917       fixed defect    2
# 918                NaN    0
# 919                NaN    1
#
# [920 rows x 16 columns]

# %% [markdown]
# ## 4. Feature Transformation

# %%
from sklearn.preprocessing import LabelEncoder

label_encoders = {}
for col in ['sex', 'cp', 'thal', 'AgeGroup']:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
numerical_cols = ['chol', 'trestbps', 'thalch']
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
df
# Out:
#       id  age  sex        dataset  cp  trestbps      chol    fbs  \
# 0      1   63    1      Cleveland   3     0.725  0.386401   True
# 1      2   67    1      Cleveland   0     0.800  0.474295  False
# 2      3   67    1      Cleveland   0     0.600  0.379768  False
# 3      4   37    1      Cleveland   2     0.650  0.414594  False
# 4      5   41    0      Cleveland   1     0.650  0.338308  False
# ..   ...  ...  ...            ...  ..       ...       ...    ...
# 904  905   57    1  VA Long Beach   0     0.650  0.343284  False
# 908  909   74    1  VA Long Beach   0     0.775  0.514096  False
# 910  911   51    0  VA Long Beach   0     0.570  0.427861   True
# 911  912   62    1  VA Long Beach   0     0.800  0.421227   True
# 912  913   53    1  VA Long Beach   0     0.720  0.497512   True
#
#               restecg    thalch  exang  oldpeak        slope   ca  thal  num  \
# 0      lv hypertrophy  0.633803  False      2.3  downsloping  0.0     0    0
# 1      lv hypertrophy  0.338028   True      1.5         flat  3.0     1    2
# 2      lv hypertrophy  0.485915   True      2.6         flat  2.0     2    1
# 3              normal  0.894366  False      3.5  downsloping  0.0     1    0
# 4      lv hypertrophy  0.788732  False      1.4    upsloping  0.0     1    0
# ..                ...       ...    ...      ...          ...  ...   ...  ...
# 904  st-t abnormality  0.253521   True      1.0         flat  0.0     1    0
# 908            normal  0.366197   True      1.5  downsloping  0.0     1    2
# 910    lv hypertrophy  0.253521  False      1.0    upsloping  0.0     1    0
# 911  st-t abnormality  0.338028   True      3.0         flat  0.0     1    4
# 912  st-t abnormality  0.478873   True      1.5         flat  0.0     1    3
#
#      AgeGroup CholesterolLevel  IsRisk
# 0           2           Normal       1
# 1           2             High       1
# 2           2           Normal       1
# 3           1             High       1
# 4           0           Normal       0
# ..        ...              ...     ...
# 904         0           Normal       0
# 908         2             High       1
# 910         0             High       1
# 911         2             High       1
# 912         0             High       1
#
# [531 rows x 19 columns]

# %% [markdown]
# ## 5. Feature Interaction

# %%
df['BP_Chol_Interaction'] = df['trestbps'] * df['chol']

# %%
threshold = 100
df['ExerciseRisk'] = ((df['exang'] == 1) & (df['thalch'] < threshold)).astype(int)

# %%
df
# Out:
#       id  age  sex        dataset  cp  trestbps      chol    fbs  \
# 0      1   63    1      Cleveland   3     0.725  0.386401   True
# 1      2   67    1      Cleveland   0     0.800  0.474295  False
# 2      3   67    1      Cleveland   0     0.600  0.379768  False
# 3      4   37    1      Cleveland   2     0.650  0.414594  False
# 4      5   41    0      Cleveland   1     0.650  0.338308  False
# ..   ...  ...  ...            ...  ..       ...       ...    ...
# 904  905   57    1  VA Long Beach   0     0.650  0.343284  False
# 908  909   74    1  VA Long Beach   0     0.775  0.514096  False
# 910  911   51    0  VA Long Beach   0     0.570  0.427861   True
# 911  912   62    1  VA Long Beach   0     0.800  0.421227   True
# 912  913   53    1  VA Long Beach   0     0.720  0.497512   True
#
#               restecg    thalch  ... oldpeak        slope   ca  thal  num  \
# 0      lv hypertrophy  0.633803  ...     2.3  downsloping  0.0     0    0
# 1      lv hypertrophy  0.338028  ...     1.5         flat  3.0     1    2
# 2      lv hypertrophy  0.485915  ...     2.6         flat  2.0     2    1
# 3              normal  0.894366  ...     3.5  downsloping  0.0     1    0
# 4      lv hypertrophy  0.788732  ...     1.4    upsloping  0.0     1    0
# ..                ...       ...  ...     ...          ...  ...   ...  ...
# 904  st-t abnormality  0.253521  ...     1.0         flat  0.0     1    0
# 908            normal  0.366197  ...     1.5  downsloping  0.0     1    2
# 910    lv hypertrophy  0.253521  ...     1.0    upsloping  0.0     1    0
# 911  st-t abnormality  0.338028  ...     3.0         flat  0.0     1    4
# 912  st-t abnormality  0.478873  ...     1.5         flat  0.0     1    3
#
#      AgeGroup  CholesterolLevel IsRisk  BP_Chol_Interaction  ExerciseRisk
# 0           2            Normal      1             0.280141             0
# 1           2              High      1             0.379436             1
# 2           2            Normal      1             0.227861             1
# 3           1              High      1             0.269486             0
# 4           0            Normal      0             0.219900             0
# ..        ...               ...    ...                  ...           ...
# 904         0            Normal      0             0.223134             1
# 908         2              High      1             0.398425             1
# 910         0              High      1             0.243881             0
# 911         2              High      1             0.336982             1
# 912         0              High      1             0.358209             1
#
# [531 rows x 21 columns]
